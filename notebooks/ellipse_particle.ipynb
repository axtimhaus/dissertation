# %%
from sympy import *

# %%
r = Symbol("r", positive=True)
o = Symbol("o", positive=True)
phi = Symbol("\\phi")

# %%
a = sqrt(o) * r
b = r / sqrt(o)

# %%
(a * b).simplify()
# Out:
# r**2

# %%
(a / b).simplify()
# Out:
# o

# %%
radius = a * b / sqrt((a * sin(phi)) ** 2 + (b * cos(phi)) ** 2)

# %%
radius
# Out:
# r**2/sqrt(o*r**2*sin(\phi)**2 + r**2*cos(\phi)**2/o)

# %%
integrate(radius**2 / 2, (phi, 0, 2 * pi))
# Out:
# 0

# %%
integrate(r**2 / 2, (phi, 0, 2 * pi))
# Out:
# pi*r**2

# %%
import numpy as np
import scipy.integrate as spi

R = 1
O = 10

# %%
spi.quad(lambda t: (r**2 / 2).evalf(subs={r: R, o: O, phi: t}), 0, 2 * np.pi)
# Out:
# (3.141592653589793, 3.487868498008632e-14)

# %%
spi.quad(lambda t: (radius**2 / 2).evalf(subs={r: R, o: O, phi: t}), 0, 2 * np.pi)
# Out:
# (3.1415926535897944, 4.238079464437969e-11)

# %%
import plotly.express as px

# %%
PHIS = np.linspace(0, 2 * np.pi, 201)

# %%
lambdify(phi, radius.subs(o, O).subs(r, R))(PHIS)
# Out:
# array([3.16227766, 3.01830226, 2.68189801, 2.30830499, 1.97830478,
#        1.70928872, 1.49469251, 1.32324909, 1.18487909, 1.07175733,
#        0.97806077, 0.89949321, 0.83286923, 0.775802  , 0.72648039,
#        0.68351199, 0.64581249, 0.6125272 , 0.58297469, 0.5566059 ,
#        0.53297409, 0.51171249, 0.49251747, 0.47513576, 0.45935461,
#        0.44499416, 0.43190146, 0.41994573, 0.40901463, 0.3990112 ,
#        0.38985143, 0.38146226, 0.37378   , 0.36674892, 0.36032018,
#        0.35445091, 0.34910344, 0.34424462, 0.33984533, 0.33587999,
#        0.33232617, 0.32916429, 0.32637733, 0.32395057, 0.32187147,
#        0.32012943, 0.3187157 , 0.31762326, 0.31684673, 0.31638232,
#        0.31622777, 0.31638232, 0.31684673, 0.31762326, 0.3187157 ,
#        0.32012943, 0.32187147, 0.32395057, 0.32637733, 0.32916429,
#        0.33232617, 0.33587999, 0.33984533, 0.34424462, 0.34910344,
#        0.35445091, 0.36032018, 0.36674892, 0.37378   , 0.38146226,
#        0.38985143, 0.3990112 , 0.40901463, 0.41994573, 0.43190146,
#        0.44499416, 0.45935461, 0.47513576, 0.49251747, 0.51171249,
#        0.53297409, 0.5566059 , 0.58297469, 0.6125272 , 0.64581249,
#        0.68351199, 0.72648039, 0.775802  , 0.83286923, 0.89949321,
#        0.97806077, 1.07175733, 1.18487909, 1.32324909, 1.49469251,
#        1.70928872, 1.97830478, 2.30830499, 2.68189801, 3.01830226,
#        3.16227766, 3.01830226, 2.68189801, 2.30830499, 1.97830478,
#        1.70928872, 1.49469251, 1.32324909, 1.18487909, 1.07175733,
#        0.97806077, 0.89949321, 0.83286923, 0.775802  , 0.72648039,
#        0.68351199, 0.64581249, 0.6125272 , 0.58297469, 0.5566059 ,
#        0.53297409, 0.51171249, 0.49251747, 0.47513576, 0.45935461,
#        0.44499416, 0.43190146, 0.41994573, 0.40901463, 0.3990112 ,
#        0.38985143, 0.38146226, 0.37378   , 0.36674892, 0.36032018,
#        0.35445091, 0.34910344, 0.34424462, 0.33984533, 0.33587999,
#        0.33232617, 0.32916429, 0.32637733, 0.32395057, 0.32187147,
#        0.32012943, 0.3187157 , 0.31762326, 0.31684673, 0.31638232,
#        0.31622777, 0.31638232, 0.31684673, 0.31762326, 0.3187157 ,
#        0.32012943, 0.32187147, 0.32395057, 0.32637733, 0.32916429,
#        0.33232617, 0.33587999, 0.33984533, 0.34424462, 0.34910344,
#        0.35445091, 0.36032018, 0.36674892, 0.37378   , 0.38146226,
#        0.38985143, 0.3990112 , 0.40901463, 0.41994573, 0.43190146,
#        0.44499416, 0.45935461, 0.47513576, 0.49251747, 0.51171249,
#        0.53297409, 0.5566059 , 0.58297469, 0.6125272 , 0.64581249,
#        0.68351199, 0.72648039, 0.775802  , 0.83286923, 0.89949321,
#        0.97806077, 1.07175733, 1.18487909, 1.32324909, 1.49469251,
#        1.70928872, 1.97830478, 2.30830499, 2.68189801, 3.01830226,
#        3.16227766])

# %%
px.line_polar(r=lambdify(phi, radius.subs(o, O).subs(r, R))(PHIS), theta=np.rad2deg(PHIS))
